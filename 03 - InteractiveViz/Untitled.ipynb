# %%
import pandas as pd
import numpy as np
import json
import os
import googlemaps
from datetime import datetime
from urllib import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-571dd86adf11> in <module>()
#       3 import json
#       4 import os
# ----> 5 import googlemaps
#       6 from datetime import datetime
#       7 from urllib import *
#
# ImportError: No module named 'googlemaps'

# %%
gmaps = googlemaps.Client(key='AIzaSyAG-qCAbp882G1EjwfPU8K8_aHsBy1-6Gs')

# Geocoding an address
for i in range (5000) :
    geocode_result = gmaps.geocode('bite')
    split_loc = str(geocode_result).split(', ')
    print(split_loc[0])
    print (i)
# Out:
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 0
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 1
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 2
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 3
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 4
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 5
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 6
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 7
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 8
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 9
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 10
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 11
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 12
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 13
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 14
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 15
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 16
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 17
# [{'place_id': 'ChIJS7tbqJy9AS0Rm-7CtVCfWrg'
# 18
# ...
