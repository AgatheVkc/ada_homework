# %% [markdown]
# # HOMEWORK 3  - INTERACTIVE VIZ
#
# ** Build a Choropleth map which shows intuitively (i.e., use colors wisely) how much grant money goes to each Swiss canton. To do so, you will need to use the provided TopoJSON file, combined with the Choropleth map example you can find in the Folium README file.**
#
# **BONUS: using the map you have just built, and the geographical information contained in it, could you give a rough estimate of the difference in research funding between the areas divided by the Röstigraben?**

# %% [markdown]
# ## 1. Get the canton to which each grant was assigned

# %% [markdown]
# Usual imports first.
# - A INSTALLER AVEC pip install geopy

# %%
import pandas as pd
import numpy as np
import json
import os
from geopy.geocoders import Nominatim
from geopy.geocoders import GeoNames
from urllib import *

# %% [markdown]
# We load the grants and select a few useful attributes :
# - The university and the institution will try to help us locate the canton to which each grant was assigned.
# - The approved amount to know how much each canton received.

# %%
df_grants = pd.read_csv('P3_GrantExport.csv',sep=';')
df_grants = df_grants[[6,7,11,12,13]]
df_grants.head()
# Out:
#                                          Institution  \
# 0                                                NaN
# 1  Faculté de Psychologie et des Sciences de l'Ed...
# 2  Kommission für das Corpus philosophorum medii ...
# 3  Abt. Handschriften und Alte Drucke Bibliothek ...
# 4                       Schweiz. Thesauruskommission
#
#                                 University  Start Date    End Date  \
# 0                     Nicht zuteilbar - NA  01.10.1975  30.09.1976
# 1                Université de Genève - GE  01.10.1975  30.09.1976
# 2  NPO (Biblioth., Museen, Verwalt.) - NPO  01.03.1976  28.02.1985
# 3                   Universität Basel - BS  01.10.1975  30.09.1976
# 4  NPO (Biblioth., Museen, Verwalt.) - NPO  01.01.1976  30.04.1978
#
#   Approved Amount
# 0        11619.00
# 1        41022.00
# 2        79732.00
# 3        52627.00
# 4       120042.00

# %% [markdown]
# ### 1. Extracting the canton from the university field
# There are some issues in the data, that need to be formatted. First of all, some data need to be replaced with NaN, as they do not convey any information regarding the location of the grant that was assigned. We considered the following :
# - 'Nicht zuteilbar - NA' -> Unavailable data
# - 'NPO (Biblioth., Museen, Verwalt.) - NPO' -> No informations
# - 'Weitere Institute - FINST' -> Other institutes
# - 'Firmen/Privatwirtschaft - FP' -> Private institutions
#
# There is also a second part of data that simply have no university field. The location of where those grants were assigned then shall be determined in the second part of the extraction, where we turn our sights to the institution field of the DataFrame

# %%
df_grants = df_grants.replace('Nicht zuteilbar - NA',np.nan)
df_grants = df_grants.replace('NPO (Biblioth., Museen, Verwalt.) - NPO',np.nan)
df_grants = df_grants.replace('Weitere Institute - FINST',np.nan)
df_grants = df_grants.replace('Firmen/Privatwirtschaft - FP',np.nan)

data_uni = df_grants['University'].unique()[1:]

data_uni[1:10]
# Out:
# array(['Universität Basel - BS', 'Université de Fribourg - FR',
#        'Universität Zürich - ZH', 'Université de Lausanne - LA',
#        'Universität Bern - BE',
#        'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL',
#        'Université de Neuchâtel - NE', 'ETH Zürich - ETHZ',
#        'Inst. de Hautes Etudes Internat. et du Dév - IHEID'], dtype=object)

# %% [markdown]
# In order to do a few less queries on the web to determine the location of our universities, we define two dictionnaries that we will extensively use to help us locate a university. The first one, `CANTON_DICT` associates each canton to its tag, that we will use on the map later on, but we can use it in the following way : if the key of this dict is present in the string describing the university, then we match it to the canton. It is very practical, as many universities are located in the capital of the canton, which often has the same name as the canton itself.
#
# The second dict, `CAPITAL_DICT` contains pairs associating the capital of a canton to a canton, for those who do not have exactly the same name. We will use it the same way as `CANTON_DICT` : if the name of the capital appears in the string of the university, we match it to the canton it belongs to.

# %%
CANTON_DICT = {'Zürich':'ZH','Bern':'BE','Luzern':'LU','Uri':'UR','Schwyz':'SZ','Obwalden':'OW','Nidwalden':'NW',
               'Glarus':'GL','Zug':'ZG','Fribourg':'FR','Solothurn':'SO','Basel-Stadt':'BS','Basel-Landschaft':'BL',
               'Schaffhausen':'SH','Appenzell Ausserrhoden':'AR','Appenzell Innerrhoden':'AI','Sankt Gallen':'SG',
               'Graubünden':'GR','Aargau':'AG','Thurgau':'TG','Ticino':'TI', 'Vaud':'VD','Valais':'VS','Neuchâtel':'NE',
               'Genève':'GE','Jura':'JU','OUT': 'OUT'}
CAPITAL_DICT = {'Basel':'Basel-Stadt' ,'Lausanne':'Vaud', 'Sion':'Valais','Altdorf':'Uri','Sarnen':'Obwalden','Stans':'Nidwalden',
                'Liestal':'Basel-Landschaft','Herisau':'Appenzell Ausserrhoden',
                'Chur':'Graubünden','Aarau':'Aargau','Frauenfeld':'Thurgau','Bellinzona':'Ticino','Delémont':'Jura'}
#'Appenzell':'Appenzell Innerrhoden' excluded because the name of the city is partially in the name of two cantons

# %% [markdown]
# Let us now start with the canton extraction from the uni field. We will use two methods for that.
# - `extract_canton` will also be reused later on, tries to find, given a data_string containing a university/institution, the canton if belongs to. It does that in three steps :
#     1. Tries to see if a canton appears in the data_string
#     2. Tries to see if a capital which does not have the same name as the canton appears in the data_string
#     3. Queries the Nominatim web service to try to locate the string. Here, if the response if `None`, we return `None`, and if the answer is not in Switzerland (its last field should contain `Svizra` in this case), then we also return `None`.

# %%
def extract_canton(data_string):
    """
        Fetchs from the web the location associated to a string. We use Nominatim at the moment. 
        The format of the output string (if it is not None) has the canton in the 6th output before the end.
        The canton is written in all the languages spoken in it, and we hence split and keep the name that comes first.
        @param data_string : the data from which we want to determine the canton
        @return canton : the name of the canton associated to the input data_string
    """
    for canton in CANTON_DICT:
        if(canton in str(data_string)):
            return canton
    for city,canton in CAPITAL_DICT.items():
        if(city in str(data_string)):
            return canton
    geolocator = Nominatim()#,username='test_056')
    location = geolocator.geocode(data_string)
    split_loc = str(location).split(', ')
    if (split_loc is not None) and (split_loc[-1] =='Svizra'):
        canton = str(location).split(', ')
        canton = canton[len(canton)-6]
        return canton.split(' - ')[0]   
    elif (split_loc != ['None']):
        print(data_string)
        print(split_loc)
        return 'OUT'
    else:
        return np.nan

# %% [markdown]
# - The second method, `extract_canton_from_uni`, will simply iterate on all the different universites of our DataFrame and call extract_canton. To get a higher chance of succeeding, we split the string at the `-` that separates the name and the acronym, and if the research was not successful with the full name, we pass the acronym to extract_canton as well. The full processing is done only once, and we store the result as a json file to load it again later on.

# %%
def extract_canton_from_uni(data_uni):
    """
        Extracts to which canton belongs a university and stored it into a json file (folder data).
        @param data_uni :           an array of strings describing universities or other institutions.
        @return university_dict :   a dict which associate to each university a canton if it was found
                                    or a None if nothing was found.
    """
    file = 'data/uni_canton_dict4.json'
    if(os.path.isfile(file)):
        print('Loading the data from json file')
        with open(file) as f:
            university_dict = json.load(f)
    else:
        print('Fetching the locations from the web')
        university_dict = dict()
        for uni in data_uni:
            # Splits the university string at the '-', which usually corresponds to the separation between the full name
            # and the acronym of the institution.
            uni_name_split = uni.split(' - ')
            extract_value = extract_canton(uni_name_split[0])
            if (extract_value is 'OUT') and (len(uni_name_split) > 1):
                # If the canton was not found in the name, then we try to extract it from the acronym string if it exists
                extract_value = extract_canton(uni_name_split[1])
            university_dict[uni] = extract_value
        with open(file, 'w') as f:
            json.dump(university_dict, f)
    return university_dict
university_canton = extract_canton_from_uni(data_uni)
#university_canton
# Out:
# Loading the data from json file

# %%
university_canton
# Out:
# {'AO Research Institute - AORI': 'OUT',
#  'Allergie- und Asthmaforschung - SIAF': nan,
#  'Berner Fachhochschule - BFH': 'Bern',
#  'Biotechnologie Institut Thurgau - BITG': 'Thurgau',
#  "Centre de rech. sur l'environnement alpin - CREALP": nan,
#  'EPF Lausanne - EPFL': 'Vaud',
#  'ETH Zürich - ETHZ': 'Zürich',
#  'Eidg. Anstalt für Wasserversorgung - EAWAG': nan,
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL': nan,
#  'Eidg. Hochschulinstitut für Berufsbildung - EHB': nan,
#  'Eidg. Material und Prüfungsanstalt - EMPA': nan,
#  'Ente Ospedaliero Cantonale - EOC': 'Ticino',
#  'Fachhochschule Kalaidos - FHKD': nan,
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW': nan,
#  'Fachhochschule Ostschweiz - FHO': nan,
#  'Facoltà di Teologia di Lugano - FTL': nan,
#  'Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS': nan,
#  'Forschungsanstalten Agroscope - AGS': nan,
#  'Forschungsinstitut für Opthalmologie - IRO': nan,
#  'Forschungsinstitut für biologischen Landbau - FIBL': 'Aargau',
#  'Forschungskommission SAGW': nan,
#  'Franklin University Switzerland - FUS': 'Ticino',
#  'Friedrich Miescher Institute - FMI': nan,
#  'HES de Suisse occidentale - HES-SO': nan,
#  'Haute école pédagogique BE, JU, NE - HEPBEJUNE': nan,
#  'Haute école pédagogique du canton de Vaud - HEPL': 'Vaud',
#  'Haute école pédagogique fribourgeoise - HEPFR': nan,
#  'Hochschule Luzern - HSLU': 'Luzern',
#  'Idiap Research Institute - IDIAP': 'Valais',
#  'Inst. Suisse de Spéléologie et Karstologie - ISSKA': nan,
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID': nan,
#  'Inst. universit. romand de Santé au Travail - IST': nan,
#  'Institut Universitaire Kurt Bösch - IUKB': nan,
#  'Institut für Kulturforschung Graubünden - IKG': 'Graubünden',
#  'Instituto Ricerche Solari Locarno - IRSOL': nan,
#  'Interkant. Hochschule für Heilpädagogik ZH - HfH': nan,
#  'Istituto Svizzero di Roma - ISR': nan,
#  'Kantonsspital St. Gallen - KSPSG': 'Sankt Gallen',
#  'Paul Scherrer Institut - PSI': 'Aargau',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD': nan,
#  'Pädag. Hochschule Tessin (Teilschule SUPSI) - ASP': nan,
#  'Pädagogische Hochschule Bern - PHBern': 'Bern',
#  'Pädagogische Hochschule Graubünden - PHGR': 'Graubünden',
#  'Pädagogische Hochschule Luzern - PHLU': 'Luzern',
#  'Pädagogische Hochschule Nordwestschweiz - PHFHNW': nan,
#  'Pädagogische Hochschule Schaffhausen - PHSH': 'Schaffhausen',
#  'Pädagogische Hochschule Schwyz - PHSZ': 'Schwyz',
#  'Pädagogische Hochschule St. Gallen - PHSG': 'Sankt Gallen',
#  'Pädagogische Hochschule Thurgau - PHTG': 'Thurgau',
#  'Pädagogische Hochschule Wallis - PHVS': nan,
#  'Pädagogische Hochschule Zug - PHZG': 'Zug',
#  'Pädagogische Hochschule Zürich - PHZFH': 'Zürich',
#  'Robert Walser-Stiftung Bern - RWS': 'Bern',
#  'SUP della Svizzera italiana - SUPSI': nan,
#  'Schweiz. Hochschule für Logopädie Rorschach - SHLR': nan,
#  'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA': nan,
#  'Schweizer Kompetenzzentrum Sozialwissensch. - FORS': nan,
#  'Schweizer Paraplegiker Forschung - SPF': nan,
#  'Staatsunabh. Theologische Hochschule Basel - STHB': 'Basel-Stadt',
#  'Swiss Center for Electronics and Microtech. - CSEM': nan,
#  'Swiss Institute of Bioinformatics - SIB': nan,
#  'Università della Svizzera italiana - USI': 'Ticino',
#  'Universität Basel - BS': 'Basel-Stadt',
#  'Universität Bern - BE': 'Bern',
#  'Universität Luzern - LU': 'Luzern',
#  'Universität St. Gallen - SG': 'Sankt Gallen',
#  'Universität Zürich - ZH': 'Zürich',
#  'Université de Fribourg - FR': 'Fribourg',
#  'Université de Genève - GE': 'Genève',
#  'Université de Lausanne - LA': 'Vaud',
#  'Université de Neuchâtel - NE': 'Neuchâtel',
#  'Weitere Spitäler - ASPIT': nan,
#  'Zürcher Fachhochschule (ohne PH) - ZFH': nan}

# %% [markdown]
# Let us now see the number of universities that were located and those who weren't.

# %%
print(len([place for place, value in university_canton.items() if not pd.isnull(value)]))
print(len([place for place, value in university_canton.items() if pd.isnull(value)]))
# Out:
# 35
# 38

# %% [markdown]
# Sadly, this way only half of the universities were matches. Note that we did several tests and found that GeoNames leads a way poorer result than Nominatim (52 vs 37 not found), and prefiltering (trying to find the uni in the `CANTON_DICT` and `CAPITAL_DICT` dict) yields 37 not found against 40, but avoid queries on the web.

# %% [markdown]
# Let us now add a column to our grant DataFrame to find how many of the projects have been identified from their university name and fill this column with the canton tags from each canton

# %%
df_grants['Canton'] = np.nan
match_canton_uni = lambda uni: CANTON_DICT[university_canton[uni]] if (not pd.isnull(university_canton[uni])) else university_canton[uni]
df_grants.Canton = df_grants.University.loc[[uni in university_canton for uni  in df_grants.University]].apply(match_canton_uni)

# %%
df_grants.head(100)
# Out:
#                                           Institution  \
# 0                                                 NaN
# 1         41022.00     GE
# 2         79732.00    NaN
# 3         52627.00     BS
# 4        120042.00    NaN
# 5         53009.00     FR
# 6         25403.00     FR
# 7         47100.00     ZH
# 8         25814.00     VD
# 9        360000.00     GE
# 10       153886.00     FR
# 11       862200.00    NaN
# 12       116991.00     GE
# 13       112664.00     BS
# 14         5000.00     ZH
# 15       204018.00     FR
# 16       149485.00     GE
# 17        83983.00     ZH
# 18        38152.00    NaN
# 19        14138.00     VD
# 20       164602.00     GE
# 21       147795.00     BE
# 22        24552.00     ZH
# 23        44802.00     GE
# 24        56000.00    NaN
# 25       152535.00    NaN
# 26       225000.00    NaN
# 27       179124.00    NaN
# 28        20000.00     ZH
# 29       445198.00    NaN
# ..             ...    ...
# 70        24000.00     GE
# 71        65004.00     FR
# 72         4500.00     ZH
# 73       170000.00    NaN
# 74       144814.00     ZH
# 75       132548.00    NaN
# 76        10402.00     ZH
# 77        41872.00     ZH
# 78       137040.00    NaN
# 79       117101.00     BE
# 80       100000.00    NaN
# 81         2000.00     BE
# 82        20689.00     SG
# 83        19980.00    NaN
# 84        16000.00    NaN
# 85       123335.00     ZH
# 86        20095.00     ZH
# 87        14500.00    NaN
# 88        34281.00     SG
# 89        27000.00    NaN
# 90        23881.00     ZH
# 91       326856.00     ZH
# 92        38652.00     ZH
# 93        99995.00     ZH
# 94        69000.00    NaN
# 95      1062788.00    NaN
# 96        55927.00     GE
# 97        29420.00    NaN
# 98       139988.00     GE
# 99        17000.00     VD
#
# [100 rows x 6 columns]

# %%
print(len(df_grants[df_grants.Canton.isnull()]) / len(df_grants.Canton))
print(len(df_grants[df_grants.University.isnull() & df_grants.Institution.isnull()]) / len(df_grants.Canton))
df_grants[df_grants.Canton.isnull()]
# Out:
# 0.315480936078413
# 0.06257718582438368
#                                              Institution  \
# 0                                                    NaN
# 2      Kommission für das Corpus philosophorum medii ...
# 4                           Schweiz. Thesauruskommission
# 11     Schweizerische Rechtsquellen c/o Universität Z...
# 18                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26            Schweizerische Gesellschaft für Volkskunde
# 27                         Kuratorium Carl J. Burckhardt
# 29     Eidg. Forschungsanstalt für Wald, Schnee und L...
# 30     Schweizerisches Nationalmuseum Landesmuseum Zü...
# 31     Fondation Hardt pour l'étude de l'Antiquité cl...
# 33     Historische und Antiquarische Gesellschaft zu ...
# 35         Schweizerisches Institut für Volkskunde (SIV)
# 36                                                   NaN
# 37     Bibliothèque de Genève Département des périodi...
# 41                                                   NaN
# 50                                                   NaN
# 52     Kommission zur Herausgabe der Basler Rektorats...
# 54                         Collège secondaire de Béthusy
# 56             Département des Sciences Politiques IUHEI
# 58                                        Forum Ost-West
# 62                                     AGGS Staatsarchiv
# 65                                     AGGS Staatsarchiv
# 68                        Schweizerischer Juristenverein
# 73                                         Antikenmuseum
# 75                            Stiftung "Pro Innerrhoden"
# 78     IHEID Fondation pour l'institut de hautes étud...
# 80                                                   NaN
# 83     Institut für psychologische Forschung und Bera...
# ...                                                  ...
# UNI: EPFL Dépt. de Génie Civil  Lausanne CH                                                        1
# UNI: Massachussetts Institute of Technology Center for theoretical Physics  Cambridge, M A USA     1
# Department of Mathematics University of California, Los Angeles                                    1
# UNI: MAPs. Harvard Universityealthal Centera u  Dept of Cellular and USA                           1
# Plasma Science and Fusion Center (PSFC) Massachusetts Institute of Technology (MIT)                1
# Johns Hopkins Dept. of Orthopaedic Surgery The Ross Research Building                              1
# Centro de Medicina Regenerativa de Barcelona                                                       1
# UNI: University of California Department of Slavic Languages and Literatures Berkeley US A         1
# Department of Biological Chemistry John Innes Centre                                               1
# Konkordat der Schweizerischen Krankenkassen                                                        1
# UNI: Weizmann Institute of Science Dept of M embrane Research  Rehovot IL                          1
# Dept. of Chemistry and Material Sciences University of Illinois at Urbana-Champaign                1
# Name: Institution, dtype: int64

# %% [markdown]
# We see that those institutions are mostly foreign universities or reasearch centers, that do not provide useful informations for our exercise. However, there are some swiss universities in the middle of it, so we will need to iterate through it and sort the institutions that will be kept or not.

# %%
df_institution = df_grants['Institution'].loc[df_grants['Canton'].isnull()]
df_institution = df_institution.unique()#head()
print(df_institution)
print(df_institution.shape)
# Out:
# [nan 'Kommission für das Corpus philosophorum medii aevi der SGG'
#  'Schweiz. Thesauruskommission' ...,
#  'Zoologisches Institut Universität Basel'
#  'Abteilung für Neuropsychologie Zentrum für Kognitionswissenschaften Universität Bremen'
#  'Departement Design Zürcher Hochschule der Künste ZHdK']
# (9540,)

# %% [markdown]
# The `function extract_canton_from_institution` will act the same way as `extract_canton_from_uni`, iterating over all the entries of institution we need (i.e. all the fields that were not found through the university canton extraction) and stores as well the result in a json.
#
# Note that as the number of institution is way larger than the number of universites, doing all our queries in one time will not be possible, due to the limitations from the website we're using. As we want to have the most consistent results as possible, we used the same website (Nominatim) for all the queries and simply waited when we had gone over the maximum number of queries we could make (around 2500 queries per person). We can easily recognise when we made too much queries, as our classification will return `NOT_FOUND` each time, meaning that the request timed out and that an exception was thrown, which we catches.

# %%
def extract_canton_from_institution(data_institution, complete = True):
    """
        Extracts to which canton belongs a institution and stored it into a json file (folder data). 
        As this data is very large, the queries to the website will most likely time out. We dump the the dictionnary 
        to a json file at each iteration and can restart from it with the parameter complete
        @param data_institution :   an array of strings describing institutions.
        @param complete         :   tells us if the process has been completed (everything saved to json file)
        @return institution_dict :  a dict which associate to each university a canton if it was found
                                    or a None if nothing was found.
    """
    institution_dict = dict()
    if(os.path.isfile('data/instit_canton_dict.json')):
        print('Loading the data from json file')
        with open('data/instit_canton_dict.json') as f:
            institution_dict = json.load(f)
    # We keep on sampling if the boolean complete is False, meaning that everything was not sampled yet.
    if not(os.path.isfile('data/instit_canton_dict.json') and complete):
        print('Fetching the locations from the web')
        for index,instit in enumerate(data_institution):
            try:
                value = extract_canton(instit)
            except :
                #We catch the exception linked to the fact that the request timed out, and print 'NOT_FOUND'
                #It is useful to realise that the we passed the limit number of requests we can ask to the server
                value = np.nan
                institution_dict[instit] = np.nan
                print(index,'- NOT FOUND <===== ',instit,)
            institution_dict[instit] = value
            if value is not np.nan:
                print(index,'-',value,'<=====',instit )
        #We save in the json at the end of each iteration
        with open('data/instit_canton_dict.json', 'w') as f:
            json.dump(institution_dict, f)
            excluded_bool = False
    return institution_dict
institution_canton = extract_canton_from_institution(df_institution[9000:],complete=True)
# Out:
# Loading the data from json file
# Fetching the locations from the web
# Institut für Theoretische Astrophysik Universität Heidelberg
# ['Institut für Theoretische Astrophysik', '2', 'Albert-Ueberle-Straße', 'Neuenheim', 'Heidelberg', 'Regierungsbezirk Karlsruhe', 'Baden-Württemberg', '69120', 'Deutschland']
# 5 - OUT <===== Institut für Theoretische Astrophysik Universität Heidelberg
# 11 - Vaud <===== SIK-ISEA Antenne romande Université de Lausanne
# 13 - Basel-Stadt <===== Abteilung Geowissenschaften Naturhistorisches Museum Basel
# 15 - Zürich <===== ZHAW Zürcher Hochschule für Angewandte Wissenschaften
# 16 - Graubünden <===== Archäologischer Dienst Graubünden Amt für Kultur
# 18 - Genève <===== Département d'économie Université de Genève
# 22 - Basel-Landschaft <===== Pädagogische Hochschule FHNW
# 24 - Bern <===== Institut für Virologie und Immunologie Depart. Infektionskrankheiten und Pathologie Universität Bern
# 52 - Bern <===== Haute Ecole Pédagogique
# James Cook University
# ['James.Cook.University', 'Upper Thomson Road', 'Thomson', 'Singapore', 'Central Singapore Community Development Council', 'Singapore']
# 76 - OUT <===== James Cook University
# Institut national d'études démographiques INED
# ['INED', 'Rue Nicolas', 'Saint-Blaise', 'Charonne', '20e', 'Paris', 'Île-de-France', '75020', 'France']
# 88 - OUT <===== Institut national d'études démographiques INED
# 115 - NOT FOUND <=====  U.F.R. Lettres, Arts et Cinéma (LAC) Université Paris Diderot - Paris 7
# Åbo Akademi University
# ['Husö biological station', 'Ekholmsvägen', 'Finström', 'Ålands landsbygd', 'Landskapet Åland', 'Regional State Agency Åland', 'Åland', 'Suomi']
# 124 - OUT <===== Åbo Akademi University
# Indian Institute Human Settlements
# ['IIHS Bangalore City Campus', '197/36', 'Sankey Tank Road', 'Lower Palace Orchard', 'Guttahalli', 'Bengaluru', 'Bangalore Urban', 'Karnataka', '560080', 'India']
# 126 - OUT <===== Indian Institute Human Settlements
# Université de Pau et des Pays de l'Adour
# ['UPPA', "Avenue de l'Université", 'Lotissement Les Jardins du Béarn', 'Pau Nord', 'Pau', 'Pyrénées-Atlantiques', 'Nouvelle-Aquitaine', '64012', 'France']
# 132 - OUT <===== Université de Pau et des Pays de l'Adour
# Center for International Forestry Research CIFOR
# ['Center for International Forestry Research (CIFOR)', 'Jalan CIFOR', 'Situ Gede', 'Jawa Barat', '16115', 'Indonesia']
# 133 - OUT <===== Center for International Forestry Research CIFOR
# Max-Planck-Institut für Kernphysik
# ['MPIK', 'Saupfercheckweg', 'Königstuhl', 'Altstadt', 'Speyererhof', 'Heidelberg', 'Regierungsbezirk Karlsruhe', 'Baden-Württemberg', '69117', 'Deutschland']
# 138 - OUT <===== Max-Planck-Institut für Kernphysik
# Oxford University Museum of Natural History
# ['Oxford University Museum of Natural History', 'Parks Road', 'Norham Manor', 'Oxford', 'Oxon', 'South East', 'England', 'OX1 3PW', 'UK']
# 168 - OUT <===== Oxford University Museum of Natural History
# 194 - Valais <===== Institut Travail Social HES-SO Valais/Wallis
# 196 - Zürich <===== ZHAW
# 197 - Genève <===== Département de Psychologie Université de Genève
# 200 - Genève <===== Haute école de travail social de Genève HETS-IES
# 204 - Bern <===== Departement Klinische Forschung Inselspital Bern Universität Bern
# 205 - Zürich <===== Klinik für Immunologie Departement Innere Medizin Universitätsspital Zürich
# 207 - Zürich <===== Neurologische Klinik Universitätsspital Zürich
# 210 - Basel-Stadt <===== Transplantationsimmunologie und Nephrologie Universitätsspital Basel
# 212 - Zürich <===== Forschung für Infektions- und Krebskrankh. Abteilung Onkologie Universitäts-Kinderspital Zürich
# Harvard University Harvard Forest
# ['Harvard University', 'Soldiers Field Road', 'Allston', 'Boston', 'Suffolk County', 'Massachusetts', '02163', 'United States of America']
# 229 - OUT <===== Harvard University Harvard Forest
# Center for Infectious Disease Research
# ['Center for Infectious Disease Research', 'Twinpalm Road', 'Chainda', 'Lusaka', 'Lusaka Province', 'Zambia']
# 252 - OUT <===== Center for Infectious Disease Research
# London Center for Nanotechnology
# ['London Centre for Nanotechnology', '17-19', 'Gordon Street', 'Holborn', 'Somers Town', 'London Borough of Camden', 'London', 'Greater London', 'England', 'WC1H 0AH', 'UK']
# 284 - OUT <===== London Center for Nanotechnology
# Toulouse School of Economics
# ['Toulouse School of Economics', 'Toulouse Centre', 'Toulouse', 'Haute-Garonne', 'Occitanie', '31000', 'France']
# 292 - OUT <===== Toulouse School of Economics
# Université de Limoges
# ['Université de Limoges', 'Rue François Mitterrand', 'La Cité', 'Clos Moreau', 'Limoges', 'Haute-Vienne', 'Nouvelle-Aquitaine', '87000;87100;87280', 'France']
# 307 - OUT <===== Université de Limoges
# Amsterdam Law School
# ['Law and Public Service High School', 'Amsterdam Avenue', 'Washington Heights', 'Manhattan', 'New York County', 'NYC', 'New York', '10040', 'United States of America']
# 323 - OUT <===== Amsterdam Law School
# Staatliche Akademie der Bildenden Künste
# ['Staatliche Akademie der bildenden Künste', '1', 'Am Weißenhof', 'Weißenhof', 'Stuttgart-Nord', 'Stuttgart', 'Regierungsbezirk Stuttgart', 'Baden-Württemberg', '70191', 'Deutschland']
# 326 - OUT <===== Staatliche Akademie der Bildenden Künste
# University of Reading
# ['University of Reading', 'London Road Campus', 'Acacia Road', 'Church', 'Whitley', 'Reading', 'South East', 'England', 'RG1 5BD', 'UK']
# 330 - OUT <===== University of Reading
# Vlerick Business School
# ['Vlerick Business School', 'Seminariestraat', 'Zuid', 'Gent', 'Oost-Vlaanderen', 'Vlaanderen', '9000', 'België - Belgique - Belgien']
# 334 - OUT <===== Vlerick Business School
# Institut Pasteur Lille
# ['Institut Pasteur', 'Boulevard Louis XIV', 'Zone Urbaine Lille', 'Lille', 'Nord', 'Hauts-de-France', '59000', 'France']
# 336 - OUT <===== Institut Pasteur Lille
# University of California-Santa Barbara
# ['University of California - Santa Barbara', 'Santa Barbara County', 'California', 'United States of America']
# 339 - OUT <===== University of California-Santa Barbara
# Universidad de Malaga
# ['Universidad de Málaga', 'Calle Puerto Parejo', 'El Ejido', 'Málaga', 'Andalucía', '29012', 'España']
# 342 - OUT <===== Universidad de Malaga
# Technische Universität München
# ['TUM', '21', 'Arcisstraße', 'Bezirksteil Königsplatz', 'Stadtbezirk 03 Maxvorstadt', 'München', 'OB', 'Bayern', '80333', 'Deutschland']
# 351 - OUT <===== Technische Universität München
# Universitat Politècnica de Catalunya
# ['ETSAV', 'Carrer de Vallseca', 'Sant Cugat del Vallès', 'Vallès Occidental', 'BCN', 'CAT', '08190', 'España']
# 366 - OUT <===== Universitat Politècnica de Catalunya
# 378 - NOT FOUND <=====  Département d’Allemand Université Sorbonne Nouvelle-Paris 3
# Joint Institute for Nuclear Research
# ['ОИЯИ', 'Новое шоссе', 'Чёрная речка', 'Дубна', 'городской округ Дубна', 'Московская область', 'ЦФО', '141981', 'РФ']
# 399 - OUT <===== Joint Institute for Nuclear Research
# Botanic Garden Meise
# ['Botanic Garden Meise', '38', 'Nieuwelaan', 'Meise', 'Halle-Vilvoorde', 'Vlaams-Brabant', 'Vlaanderen', '1860', 'België - Belgique - Belgien']
# 400 - OUT <===== Botanic Garden Meise
# 409 - Vaud <===== Droit international public Faculté de droit et des sciences criminelles Université de Lausanne
# 415 - Fribourg <===== Domaine Histoire de l'art et Archéologie Département des sciences historiques Université de Fribourg
# 416 - Vaud <===== Hôpital Ophtalmique Jules Gonin
# Hôpital Robert Debré
# ['Hôpital Robert Debré', 'Boulevard Périphérique Intérieur', 'Amérique', '19e', 'Paris', 'Île-de-France', '75019', 'France']
# 440 - OUT <===== Hôpital Robert Debré
# Faculty of Divinity University of Cambridge
# ['Faculty of Divinity', 'West Road', 'Newnham Ward', 'Cambridge', 'Cambridgeshire', 'East of England', 'England', 'CB3 9BS', 'UK']
# 454 - OUT <===== Faculty of Divinity University of Cambridge
# Institut National de Criminalistique et de Criminologie
# ['INCC', 'RN 11', 'Club des Pins', 'La Trappe', 'Cheraga', 'Daïra Cheraga', 'Alger - الجزائر', '16101', 'RADP']
# 474 - OUT <===== Institut National de Criminalistique et de Criminologie
# Max-Planck-Institut für Chemie Otto-Hahn-Institut
# ['Max-Planck-Institut für Chemie', '1', 'Hahn-Meitner-Weg', 'Oberstadt', 'Mainz', 'Rheinland-Pfalz', '55128', 'Deutschland']
# 488 - OUT <===== Max-Planck-Institut für Chemie Otto-Hahn-Institut
# IANIGLA-CONICET
# ['Instituto Argentino de Nivología', 'Glaciología y Ciencias Ambientales (IANIGLA)', 'Avenida Adrián Ruiz Leal', 'Champagnat', 'Ciudad de Mendoza', 'Sección 9ª Parque General San Martín', 'Departamento Capital', 'Mza.', 'M5500CJK', 'Argentina']
# 491 - OUT <===== IANIGLA-CONICET
# Medical College of Wisconsin
# ['Medical College of Wisconsin-Central Wisconsin', '333', 'Pine Ridge Boulevard', 'Wausau', 'Marathon County', 'Wisconsin', '54401', 'United States of America']
# 501 - OUT <===== Medical College of Wisconsin
# The Natural History Museum
# ['Natural History Museum', 'Cromwell Road', 'Brompton', 'Royal Borough of Kensington and Chelsea', 'London', 'Greater London', 'England', 'SW7 3ES', 'UK']
# 506 - OUT <===== The Natural History Museum
# Monash University
# ['Monash University', 'Queens Avenue', 'Caulfield East', 'City of Glen Eira', 'Greater Melbourne', 'Victoria', '3145', 'Australia']
# 507 - OUT <===== Monash University
# Institut National d'Etudes démographiques INED
# ['INED', 'Rue Nicolas', 'Saint-Blaise', 'Charonne', '20e', 'Paris', 'Île-de-France', '75020', 'France']
# 520 - OUT <===== Institut National d'Etudes démographiques INED
# 529 - Basel-Stadt <===== Theologische Hochschule Basel
# 534 - Zürich <===== Departement Geographie, SIE Universität Zürich
# 537 - Basel-Stadt <===== Zoologisches Institut Universität Basel

# %% [markdown]
# Let us now make sure that we treated every institution, by just seeing the length of the dictionnary we have. It is the same length as `df_institutions` as it only has unique entries.

# %%
#Gets the lengths of the dictionnary stored so we can know where to sample from on the next run.
with open('data/instit_canton_dict.json') as f:
            institution_dict = json.load(f)
print(len(institution_dict))

# %%
df_instit = df_grants.copy()
df_instit['Canton'] = np.nan
match_canton_insti = lambda uni: CANTON_DICT[institution_canton[uni]] if (not pd.isnull(institution_canton[uni])) else institution_canton[uni]
df_instit.Canton = df_instit.Institution.loc[[uni in institution_canton for uni  in df_instit.Institution]].apply(match_canton_insti)

# %%
df_grants.head(12)

# %%
df_instit.head(12)

# %%
for index in df_grants.index :
 
 if df_grants.Canton.loc[index] != df_grants.Canton.loc[index] :
    df_grants.Canton.loc[index] = df_instit.Canton.loc[index]

df_grants.head(12)

# %%
sum(df_grants.Canton.isnull()/len(df_grants.Canton))

# %%
#print (df_grants[[df_grants['Approved Amount']=='data not included in P3']])
new = df_grants[df_grants['Approved Amount']!='data not included in P3']

# %% [markdown]
# ### 3. Drawing the Switzerland map

# %%
final = pd.DataFrame(columns=['prix'])
final.indexes=['Canton']
final

# %%
for canton in CANTON_DICT :
 x = new[df_grants['Canton']==CANTON_DICT[canton]]['Approved Amount'].values
 x = x.astype(np.float)
 final.loc[CANTON_DICT[canton]]=[np.sum(x)/1e6]

final.head()
final = final.reset_index()
final.head()
final.to_csv('grants.csv')

# %%
import folium
import pandas as pd

state_geo = r'data/ch-cantons.topojson.json'
state_grants = r'data/grants.csv'

state_data = pd.read_csv(state_grants)

print(state_data)

#Let Folium determine the scale
#ice_map = folium.Map(location=[-59.1759, -11.6016],
#                   tiles='Mapbox Bright', zoom_start=2)
#ice_map.choropleth(geo_path=state_geo, topojson='objects.cantons')
color_map = folium.Map(location=[48, -102], zoom_start=3)
color_map.choropleth(geo_path=state_geo,topojson='objects.cantons', data=state_data,
             columns=['index', 'prix'],
             key_on='id',
             fill_color='YlGn', fill_opacity=0.7, line_opacity=0.2,
             legend_name='canton price (MCHF)')
color_map
